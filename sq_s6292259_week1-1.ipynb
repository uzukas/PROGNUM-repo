# %% [markdown]
# Answers for Week 1
#
# * Name: Ugnius
# * Username: uzukas
# * Student s-number: S6292259
# * Group (AS1, etc.): AS6

# %%
x = 22/7
# Out:
# 3.142857142857143

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![markiplier.jpg](attachment:e38f9aad-ee16-49ed-8911-28d26cdd34a8.jpg)

# %%
x = 6
x *= 5
x *= 4
x *= 3
x *= 2
x *= 1
print(x)
# Out:
# 720

# %%
planks_constant = 6.6*10**-34 #joule-seconds
speed_of_light = 3*10**8 #m/s
frequency = 2.42*10**28 #Hz
wavelength = speed_of_light/frequency
energy = planks_constant*speed_of_light/wavelength

print(energy)
# Out:
# 1.5971999999999995e-05

# %%
import scipy.constants as u

m_moon = 7.342*10**22
m_earth = 5.9722*10**24
distance = 385000600

force = u.G*m_moon*m_earth/distance**2

print(f"The force is {force}N")
# Out:
# The force is 1.974384051807571e+20N

# %%
from scipy.constants import G,pi

a = 150000000000
P = 365*24*60*60
total_mass = 4*pi**2*a**3/(G*P**2)

print(total_mass)
# Out:
# 2.0073105924747266e+30

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")

#the result is a combination of 10+3.14..., but not as a mathematical operation, but a combination of strings as end="" skips the usual new line between prints
# Out:
# 103.142857142857143
