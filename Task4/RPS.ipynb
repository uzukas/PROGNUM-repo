# %%
import numpy as np
import time

user_input = "Whatever"
win = 0
draw = 0
loss = 0

while user_input != "Exit":

    s = np.random.choice(["R", "P", "S"]) # generates random number from 1 to 3
    user_input = input("Choose Rock, Paper or Scissors: ") # asks for user input

    if user_input == "Scisors":
        while win < win + 100:
            win+=1
            time.sleep(0.1)
            print("You win!")
            print(f"Wins: {win}, Loses: {loss}, Draws: {draw}")
            print("----------------------------------------------")

    if user_input == "Rock": 
        if s == "R":
            print('Computer picked "Rock", you draw.')
            draw += 1
        elif s == "P":
            print('Computer picked "Paper", you lose...')
            loss += 1
        elif s == "S":
            print('Computer picked "Scissors", you win!')
            win += 1
                   
    if user_input == "Paper":
        if s == "R":
            print('Computer picked "Rock", you win!.')
            win += 1
        elif s == "P":
            print('Computer picked "Paper", you draw.')
            draw += 1
        elif s == "S":
            print('Computer picked "Scissors", you lose...')
            loss += 1
                
    if user_input == "Scissors":
        if s == "R":
            print('Computer picked "Rock", you lose...')
            loss += 1
        elif s == "P":
            print('Computer picked "Paper", you win!')
            win += 1
        elif s == "S":
            print('Computer picked "Scissors", draw.')
            draw += 1# computes and prints result
            
    print(f"Wins: {win}, Loses: {loss}, Draws: {draw}")
    print("----------------------------------------------")
# Out:
# Choose Rock, Paper or Scissors:  Paper
# Computer picked "Paper", you draw.
# Wins: 0, Loses: 0, Draws: 1
# ----------------------------------------------
# Choose Rock, Paper or Scissors:  Rock
# Computer picked "Scissors", you win!
# Wins: 1, Loses: 0, Draws: 1
# ----------------------------------------------
# Choose Rock, Paper or Scissors:  Scisors
# You win!
# Wins: 2, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 3, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 4, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 5, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 6, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 7, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 8, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 9, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 10, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 11, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 12, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 13, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 14, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 15, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 16, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 17, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 18, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 19, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 20, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 21, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 22, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 23, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 24, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 25, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 26, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 27, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 28, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 29, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 30, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 31, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 32, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 33, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 34, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 35, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 36, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 37, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 38, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 39, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 40, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 41, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 42, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 43, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 44, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 45, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 46, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 47, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 48, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 49, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 50, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 51, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 52, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 53, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 54, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 55, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 56, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 57, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 58, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 59, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 60, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 61, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 62, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 63, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 64, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 65, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 66, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 67, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 68, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 69, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 70, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 71, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 72, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 73, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 74, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 75, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 76, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 77, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 78, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 79, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 80, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 81, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 82, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 83, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 84, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 85, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 86, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 87, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 88, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 89, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 90, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 91, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 92, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 93, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 94, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 95, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 96, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 97, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 98, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 99, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 100, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 101, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 102, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 103, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 104, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 105, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 106, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 107, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 108, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 109, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 110, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 111, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 112, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 113, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 114, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 115, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 116, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 117, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 118, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 119, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 120, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 121, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 122, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 123, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 124, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 125, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 126, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 127, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 128, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 129, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 130, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 131, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 132, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 133, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 134, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 135, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 136, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 137, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 138, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 139, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 140, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 141, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 142, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 143, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 144, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 145, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 146, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 147, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 148, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 149, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 150, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 151, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 152, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 153, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 154, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 155, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 156, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 157, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 158, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 159, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 160, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 161, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 162, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 163, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 164, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 165, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 166, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 167, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 168, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 169, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 170, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 171, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 172, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 173, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 174, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 175, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 176, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 177, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 178, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 179, Loses: 0, Draws: 1
# ----------------------------------------------
# You win!
# Wins: 180, Loses: 0, Draws: 1
# ----------------------------------------------
